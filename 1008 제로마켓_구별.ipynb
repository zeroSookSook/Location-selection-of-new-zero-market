# %%
import numpy as np 
import pandas as pd

# %% [markdown]
# ## 제로마켓 지역구별 개수 확인

# %%
sample= pd.read_csv('csv_리필스테이션_최종데이터.csv',encoding='cp949')
zero_market=sample.loc[: , ["상호명","지역구"]]
zero_market
# Out:
#                           상호명   지역구
# 0                       1.5도씨   관악구
# 1             Dear.eco(디어 에코)   광진구
# 2                        감탄상회   동작구
# 3                공기(대안생활 1호점)   강동구
# 4                  공방 꽃피는 삼월에  동대문구
# 5                       굿바이마켓   용산구
# 6                        늘보따리  서대문구
# 7                  다른상점 지구자판기   동작구
# 8                         더피커   성동구
# 9                         덕분애   서초구
# 10          디어얼스(Dear. Earth)  서대문구
# 11                    물푸레지구살림   은평구
# 12                        밋자인  영등포구
# 13                       보탬상점   중랑구
# 14                      보틀라운지  서대문구
# 15                      보틀앤스쿱   마포구
# 16                       북촌감성   종로구
# 17                       비그린    동작구
# 18                       비유비웰   동작구
# 19                     세컨드페이지   송파구
# 20                       송포어스   강동구
# 21                       순환지구   성북구
# 22                       아토모스   성북구
# 23                       알맹상점   마포구
# 24                 알맹상점 리스테이션    중구
# ...

# %%
data = {"지역구": [' 관악구 ',
' 광진구 ',
' 동작구 ',
' 강동구 ',
' 동대문구 ',
' 용산구 ',
' 서대문구 ',
' 성동구 ',
' 서초구 ',
' 은평구 ',
' 영등포구 ',
' 중랑구 ',
' 마포구 ',
' 종로구 ',
' 송파구 ',
' 성북구 ',
' 중구 ',
' 노원구 ',
' 양천구 ',
' 강서구 '], '상점개수':[2 , 1 , 7 , 3 , 1 , 1 , 4 , 3 , 1 , 3 , 2 , 1 , 4 , 1 , 3 , 3 , 3 , 1 , 2 , 1 , ]}

data=pd.DataFrame(data)
data
# Out:
#        지역구  상점개수
# 0     관악구      2
# 1     광진구      1
# 2     동작구      7
# 3     강동구      3
# 4    동대문구      1
# 5     용산구      1
# 6    서대문구      4
# 7     성동구      3
# 8     서초구      1
# 9     은평구      3
# 10   영등포구      2
# 11    중랑구      1
# 12    마포구      4
# 13    종로구      1
# 14    송파구      3
# 15    성북구      3
# 16     중구      3
# 17    노원구      1
# 18    양천구      2
# 19    강서구      1

# %%
data.plot.bar()
# Out:
# <AxesSubplot:>
# C:\Users\ajm10\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 49345 (\N{HANGUL SYLLABLE SANG}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\ajm10\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 51216 (\N{HANGUL SYLLABLE JEOM}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\ajm10\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 44060 (\N{HANGUL SYLLABLE GAE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\ajm10\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 49688 (\N{HANGUL SYLLABLE SU}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# 최상위권 (7) : 동작구
#
# 중위권(3-4) : 서대문구, 마포구 // 송파, 성북, 중구, 은평, 성동, 강동

# %% [markdown]
# ## 지역구별 가구원수 비율 확인

# %% [markdown]
# 서울의 구 개수는 25개

# %%
# 몇년도 기준 데이터였지..?
gagu=pd.read_csv("가구원수별 가구수_최종데이터.csv",encoding='cp949')
gagu=gagu.iloc[0:25,0:3]
gagu=gagu.rename(columns={'동별':'지역구'}) # 위의 컬럼명과 "구"를 동일하게 변경하기 위함
gagu.sort_values(["1인가구"], ascending=False)
# Out:
#      지역구      합계    1인가구
# 20   관악구  252619  136255
# 15   강서구  249984   94436
# 23   송파구  259378   79262
# 22   강남구  211168   71986
# 18  영등포구  168518   69806
# 19   동작구  170333   68231
# 13   마포구  164080   67162
# 4    광진구  153962   66140
# 5   동대문구  153246   65290
# 7    성북구  181827   64985
# 11   은평구  193626   62447
# 10   노원구  204282   60647
# 6    중랑구  167260   60487
# 24   강동구  185441   56905
# 16   구로구  166197   54980
# 12  서대문구  134544   52792
# 8    강북구  130329   48428
# 17   금천구  107430   46827
# 21   서초구  155936   45933
# 3    성동구  122756   44946
# 14   양천구  168355   42973
# 2    용산구   96989   39270
# 9    도봉구  128439   37853
# 0    종로구   63984   27308
# 1     중구   56116   24544

# %%
for i in range(len(gagu.지역구.unique())):
    rate=gagu['1인가구']/gagu['합계']
    
rate
# Out:
# 0     0.426794
# 1     0.437380
# 2     0.404891
# 3     0.366141
# 4     0.429587
# 5     0.426047
# 6     0.361635
# 7     0.357400
# 8     0.371583
# 9     0.294716
# 10    0.296879
# 11    0.322514
# 12    0.392377
# 13    0.409325
# 14    0.255252
# 15    0.377768
# 16    0.330812
# 17    0.435884
# 18    0.414235
# 19    0.400574
# 20    0.539370
# 21    0.294563
# 22    0.340894
# 23    0.305585
# 24    0.306863
# dtype: float64

# %% [markdown]
# 합계대비 비율로도 높은 건 관악구로 보임

# %% [markdown]
# ## 데이터 프레임 1인가구 + 제로마켓 개수 병합

# %%
gagu["상점개수"] = 0
gagu.sort_values(["지역구"], ascending=False)
# Out:
#      지역구      합계    1인가구  상점개수
# 6    중랑구  167260   60487     0
# 1     중구   56116   24544     0
# 0    종로구   63984   27308     0
# 11   은평구  193626   62447     0
# 2    용산구   96989   39270     0
# 18  영등포구  168518   69806     0
# 14   양천구  168355   42973     0
# 23   송파구  259378   79262     0
# 7    성북구  181827   64985     0
# 3    성동구  122756   44946     0
# 21   서초구  155936   45933     0
# 12  서대문구  134544   52792     0
# 13   마포구  164080   67162     0
# 19   동작구  170333   68231     0
# 5   동대문구  153246   65290     0
# 9    도봉구  128439   37853     0
# 10   노원구  204282   60647     0
# 17   금천구  107430   46827     0
# 16   구로구  166197   54980     0
# 4    광진구  153962   66140     0
# 20   관악구  252619  136255     0
# 15   강서구  249984   94436     0
# 8    강북구  130329   48428     0
# 24   강동구  185441   56905     0
# 22   강남구  211168   71986     0

# %%
data.sort_values(["지역구"], ascending=False)
# Out:
#        지역구  상점개수
# 11    중랑구      1
# 16     중구      3
# 13    종로구      1
# 9     은평구      3
# 5     용산구      1
# 10   영등포구      2
# 18    양천구      2
# 14    송파구      3
# 15    성북구      3
# 7     성동구      3
# 8     서초구      1
# 6    서대문구      4
# 12    마포구      4
# 2     동작구      7
# 4    동대문구      1
# 17    노원구      1
# 1     광진구      1
# 0     관악구      2
# 19    강서구      1
# 3     강동구      3

# %%
# pd.concat([gagu,data], ignore_index=True) 를 적용했을 때 원하는 결과가 나오지 않음

gagu[gagu["지역구"]=="중랑구"].상점개수 == 1
gagu[gagu["지역구"]=="중구"].상점개수 = 3
gagu[gagu["지역구"]=="종로구"].상점개수 = 1

gagu[gagu["지역구"]=="은평구"].상점개수 = 3
gagu[gagu["지역구"]=="용산"].상점개수 = 1
gagu[gagu["지역구"]=="영등포구"].상점개수 = 2

gagu[gagu["지역구"]=="양천구"].상점개수 = 2
gagu[gagu["지역구"]=="송파구"].상점개수 = 3
gagu[gagu["지역구"]=="성북구"].상점개수 = 3

gagu[gagu["지역구"]=="성동구"].상점개수 = 3
gagu[gagu["지역구"]=="서초구"].상점개수 = 1
gagu[gagu["지역구"]=="서대문구"].상점개수 = 4

gagu[gagu["지역구"]=="마포구"].상점개수 = 4
gagu[gagu["지역구"]=="동작구"].상점개수 = 7
gagu[gagu["지역구"]=="동대문구"].상점개수 = 1

gagu[gagu["지역구"]=="노원구"].상점개수 = 1
gagu[gagu["지역구"]=="광진구"].상점개수 = 1
gagu[gagu["지역구"]=="관악구"].상점개수 = 2

gagu[gagu["지역구"]=="강서구"].상점개수 = 1
gagu[gagu["지역구"]=="강동구"].상점개수 = 3

gagu # 새로운 데이터 프레임 생성
# Out:
# C:\Users\ajm10\AppData\Local\Temp\ipykernel_4448\1025217507.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gagu[gagu["지역구"]=="중구"].상점개수 = 3
# C:\Users\ajm10\AppData\Local\Temp\ipykernel_4448\1025217507.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gagu[gagu["지역구"]=="종로구"].상점개수 = 1
# C:\Users\ajm10\AppData\Local\Temp\ipykernel_4448\1025217507.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %% [markdown]
# 이거 왜 안될까

# %% [markdown]
# ## 유동인구

# %%
subway=pd.read_csv("서울교통공사_자치구별지하철역정보_20001231.csv",encoding='cp949')
subway=subway.iloc[0:25,0:3] # 서울시기준이기 때문에 고양, 광명, 성남, 의정부시 drop
subway=subway.drop(columns=["연번"])
subway
# Out:
#      자치구                                            해당역(호선)
# 0    강남구  삼성(2), 선릉(2), 역삼(2), 강남(2), 압구정(3), 신사(3), 매봉(...
# 1    강동구  천호(5), 강동(5), 길동(5), 굽은다리(5), 명일(5), 고덕(5), 상일...
# 2    강북구                             수유(4), 미아(4), 미아사거리(4)
# 3    강서구  방화(5), 개화산(5), 김포공항(5), 송정(5), 마곡(5), 발산(5), 우...
# 4    관악구                     낙성대(2), 서울대입구(2), 봉천(2), 신림(2)
# 5    광진구  건대입구(2), 구의(2), 강변(2), 군자(5), 아차산(5), 광나루(5), ...
# 6    구로구  구로디지털단지(2), 대림(2), 신도림(2), 도림천(2), 남구로(7), 천왕(...
# 7    금천구                                         가산디지털단지(7)
# 8    노원구  당고개(4), 상계(4), 노원(4), 태릉입구(6), 화랑대(6), 수락산(7),...
# 9    도봉구                               창동(4), 쌍문(4), 도봉산(7)
# 10  동대문구             신설동(1), 제기동(1), 청량리(1), 신설동(2), 장한평(5)
# 11   동작구  사당(2), 신대방(2), 동작(4), 이수(4), 사당(4), 이수(7), 남성(...
# 12   마포구  합정(2), 홍대입구(2), 신촌(2), 이대(2), 아현(2), 마포(5), 공덕...
# 13  서대문구              충정로(2), 홍제(3), 무악재(3), 독립문(3), 충정로(5)
# 14   서초구  교대(2), 서초(2), 방배(2), 잠원(3), 고속터미널(3), 교대(3), 남...
# ...

# %% [markdown]
# ## 1인 가구 연령별

# %%
age_gagu=pd.read_csv("1인가구(연령별).csv")
age_gagu
# Out:
#     자치구별(1)  자치구별(2)     2021  2021.1  2021.2 2021.3 2021.4 2021.5  2021.6  \
# 0   자치구별(1)  자치구별(2)       합계      합계      합계     합계     합계     합계      합계
# 1   자치구별(1)  자치구별(2)       소계      소계      소계  20세미만  20세미만  20세미만  20~24세
# 2   자치구별(1)  자치구별(2)        계      남자      여자      계     남자     여자       계
# 3        합계       소계  1489893  698324  791569  10687   4021   6666  126833
# 4        합계      종로구    27308   13211   14097    328    111    217    3211
# 5        합계       중구    24544   11654   12890    268     68    200    2232
# 6        합계      용산구    39270   18124   21146    140     41     99    2620
# 7        합계      성동구    44946   22127   22819    534    212    322    4719
# 8        합계      광진구    66140   31456   34684    465    169    296    7334
# 9        합계     동대문구    65290   32424   32866   1198    457    741   11264
# 10       합계      중랑구    60487   29812   30675    169     67    102    2565
# ...
