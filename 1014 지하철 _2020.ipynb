# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib as mpl
# warnings.filterwarnings('ignore')

# %% [markdown]
# ### 서울교통공사_지차구별지하철역정보

# %%
sample2 = pd.read_csv('서울교통공사_자치구별지하철역정보.csv',encoding='CP949')
sample2 = sample2[["자치구", "해당역(호선)", "역개수"]].loc[:24]
sample2 = sample2.rename(columns={'자치구':'지역구',"해당역(호선)":"station_nm","역개수":"count"})
sample2.head()
# Out:
#    지역구                                         station_nm  count
# 0  강남구  삼성(2), 선릉(2), 역삼(2), 강남(2), 압구정(3), 신사(3), 매봉(...     13
# 1  강동구  천호(5), 강동(5), 길동(5), 굽은다리(5), 명일(5), 고덕(5), 상일...     11
# 2  강북구                             수유(4), 미아(4), 미아사거리(4)      3
# 3  강서구  방화(5), 개화산(5), 김포공항(5), 송정(5), 마곡(5), 발산(5), 우...      9
# 4  관악구                     낙성대(2), 서울대입구(2), 봉천(2), 신림(2)      4

# %%
pd.read_csv('서울교통공사_자치구별지하철역정보.csv',encoding='CP949')
# Out:
#     연번   자치구                                            해당역(호선)  역개수
# 0    1   강남구  삼성(2), 선릉(2), 역삼(2), 강남(2), 압구정(3), 신사(3), 매봉(...   13
# 1    2   강동구  천호(5), 강동(5), 길동(5), 굽은다리(5), 명일(5), 고덕(5), 상일...   11
# 2    3   강북구                             수유(4), 미아(4), 미아사거리(4)    3
# 3    4   강서구  방화(5), 개화산(5), 김포공항(5), 송정(5), 마곡(5), 발산(5), 우...    9
# 4    5   관악구                     낙성대(2), 서울대입구(2), 봉천(2), 신림(2)    4
# 5    6   광진구  건대입구(2), 구의(2), 강변(2), 군자(5), 아차산(5), 광나루(5), ...   10
# 6    7   구로구  구로디지털단지(2), 대림(2), 신도림(2), 도림천(2), 남구로(7), 천왕(...    7
# 7    8   금천구                                         가산디지털단지(7)    1
# 8    9   노원구  당고개(4), 상계(4), 노원(4), 태릉입구(6), 화랑대(6), 수락산(7),...   12
# 9   10   도봉구                               창동(4), 쌍문(4), 도봉산(7)    3
# 10  11  동대문구             신설동(1), 제기동(1), 청량리(1), 신설동(2), 장한평(5)    5
# 11  12   동작구  사당(2), 신대방(2), 동작(4), 이수(4), 사당(4), 이수(7), 남성(...   12
# 12  13   마포구  합정(2), 홍대입구(2), 신촌(2), 이대(2), 아현(2), 마포(5), 공덕...    8
# ...

# %% [markdown]
# ### 지하철_30분단위_2020

# %%
sample= pd.read_csv('지하철_30분단위_2020.csv',encoding='utf-8')
sample
# Out:
#          month  day  station_ID line_nm  station_nm  num
# 0            1    1         150     1호선         서울역    1
# 1            1    1         151     1호선          시청    0
# 2            1    1         152     1호선          종각    2
# 3            1    1         153     1호선        종로3가    1
# 4            1    1         154     1호선        종로5가    0
# ...        ...  ...         ...     ...         ...  ...
# 4712372     12   31        4709   우이신설선      북한산보국문   24
# 4712373     12   31        4710   우이신설선          정릉    4
# 4712374     12   31        4711   우이신설선  성신여대입구(돈암)    4
# 4712375     12   31        4712   우이신설선          보문   10
# 4712376     12   31        4713   우이신설선         신설동    4
#
# [4712377 rows x 6 columns]

# %%
sample[sample==0].count()
# Out:
# month              0
# day                0
# station_ID         0
# line_nm            0
# station_nm         0
# num           124402
# dtype: int64

# %%
sample[sample["num"]==0].head()
# Out:
#    month  day  station_ID line_nm    station_nm  num
# 1      1    1         151     1호선            시청    0
# 4      1    1         154     1호선          종로5가    0
# 5      1    1         155     1호선           동대문    0
# 7      1    1         157     1호선           제기동    0
# 8      1    1         158     1호선  청량리(서울시립대입구)    0

# %%
# 환승하는 역에 대해서는 결측이 발생할 수 있음
sample[(sample.station_nm == "시청") & (sample.line_nm == "2호선")&(sample.month == 1)&(sample.day == 1)].head()
# Out:
#       month  day  station_ID line_nm station_nm  num
# 130       1    1         201     2호선         시청    1
# 450       1    1         201     2호선         시청   29
# 776       1    1         201     2호선         시청   53
# 1102      1    1         201     2호선         시청   61
# 1428      1    1         201     2호선         시청   49

# %%
sample.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4712377 entries, 0 to 4712376
# Data columns (total 6 columns):
#  #   Column      Dtype
# ---  ------      -----
#  0   month       int64
#  1   day         int64
#  2   station_ID  int64
#  3   line_nm     object
#  4   station_nm  object
#  5   num         int64
# dtypes: int64(4), object(2)
# memory usage: 215.7+ MB

# %% [markdown]
# ## 365일 - 노선명 - 역명 에 해당하는 num을 포함한 df
#
# df :: 칼럼 개수 == 365일에 해당되는 각 id와 호선명에 num

# %%
df=sample.copy()
df.head()
# Out:
#    month  day  station_ID line_nm station_nm  num
# 0      1    1         150     1호선        서울역    1
# 1      1    1         151     1호선         시청    0
# 2      1    1         152     1호선         종각    2
# 3      1    1         153     1호선       종로3가    1
# 4      1    1         154     1호선       종로5가    0

# %%
df.shape
# Out:
# (4712377, 6)

# %% [markdown]
#  '낙성대',
#  '낙성대(강감찬)',
#
#  '동대문역사문화공원',
#  '동대문역사문화공원(DDP)',
#
#  '마곡나루',
#  '마곡나루(서울식물원)',
#
# '용마산',
#  '용마산(용마폭포공원)',
#
# #### 동대문역사문화공원(DDP) =/= 동대문역사문화공원
# 라고 인식함

# %%
# df[df["station_nm"] == "동대문역사문화공원"]["station_nm"]
   
# df["station_nm"] = "동대문역사문화공원(DDP)"

# 값 변경 : df.loc[행의 인덱스, 열 이름] = 바꿀 값 

df.loc[list(df[df["station_nm"] == "동대문역사문화공원"].index), "station_nm"] = "동대문역사문화공원(DDP)"

df.loc[list(df[df["station_nm"] == "마곡나루"].index), "station_nm"] = "마곡나루(서울식물원)"

df.loc[list(df[df["station_nm"] == "용마산"].index), "station_nm"] = "용마산(용마폭포공원)"

df.loc[list(df[df["station_nm"] == "낙성대"].index), "station_nm"] = "낙성대(강감찬)"

# %% [markdown]
# ## 1년에 대한 전체 합산
# 데이터 프레임 명 : subdat
# - sum_line_station : 호선 - 역명 에 대한 365일의 합산값
#
# **** 파이썬 transfrom 참고 https://pbj0812.tistory.com/458 ****

# %%
#groupdf=ex.groupby(['line_nm','station_nm'])
#ex["count_line_station"]=groupdf["station_nm"].transform('count')
#subdat=ex[["line_nm","station_nm","count_line_station"]].drop_duplicates()

#subdat = subdat.sort_values(["line_nm"],ascending=True)
#subdat = subdat.set_index(pd.Index([i for i in range(331)]))

# %%
ex = df.copy()

# line_nm, station_nm 그룹으로 묶음
## ex) 4호선-노원 , 7호선-노원 이런 식으로 한 그룹 형성
## sum_line_station 을 생성해 위의 각 속성에 해당되는 num값을 다 합해 해당 열에 값을 채움 (중복값 있는 상태)
ex["sum_line_station"] = ex.groupby(by = ['line_nm', 'station_nm'])["num"].transform(sum)

## 위에서 만든 데이터 프레임에서 월/일을 제외하고 중복값을 제거하면 1년 전체에 대한 합산 구하기 가능
subdat=ex[["line_nm","station_nm","sum_line_station"]].drop_duplicates()

## 호선명 기준으로 나열
subdat = subdat.sort_values(["line_nm"],ascending=True)
subdat = subdat.set_index(pd.Index([i for i in range(331)]))

# %%
subdat.head(10)
# Out:
#   line_nm    station_nm  sum_line_station
# 0     1호선           서울역           6656302
# 1     1호선            시청           2373206
# 2     1호선            종각           4975912
# 3     1호선          종로3가           4467501
# 4     1호선          종로5가           3587983
# 5     1호선           동대문           2177375
# 6     1호선           신설동           2529549
# 7     1호선           제기동           3392863
# 8     1호선  청량리(서울시립대입구)           3766386
# 9     1호선           동묘앞           1832455

# %%
subdat[subdat.line_nm=="1호선"] # 서울역(1,4),
# Out:
#   line_nm    station_nm  sum_line_station
# 0     1호선           서울역           6656302
# 1     1호선            시청           2373206
# 2     1호선            종각           4975912
# 3     1호선          종로3가           4467501
# 4     1호선          종로5가           3587983
# 5     1호선           동대문           2177375
# 6     1호선           신설동           2529549
# 7     1호선           제기동           3392863
# 8     1호선  청량리(서울시립대입구)           3766386
# 9     1호선           동묘앞           1832455

# %%
# 최댓값
subdat.sort_values(["sum_line_station"],ascending=False).head(5)
# Out:
#    line_nm station_nm  sum_line_station
# 57     2호선         강남          21400896
# 46     2호선   잠실(송파구청)          17166169
# 53     2호선         신림          15632652
# 51     2호선    구로디지털단지          14196523
# 25     2호선       홍대입구          13095785

# %%
# 최댓값
result.sort_values(["sum_line_station"],ascending=False)
# Out:
#          line_nm station_nm  sum_line_station
# 5            2호선         강남          21400896
# 232      2호선,8호선   잠실(송파구청)          21004378
# 19   3호선,7호선,9호선      고속터미널          18144644
# 175          2호선         신림          15632652
# 122      2호선,4호선         사당          15348165
# ..           ...        ...               ...
# 65           2호선        도림천            292749
# 237          7호선         장암            251592
# 76      9호선2~3단계       둔촌오륜            229237
# 47           4호선        남태령            215328
# 168          6호선         신내                 0
#
# [285 rows x 3 columns]

# %% [markdown]
# 만든 데이터 프레임이 확실한지 점검하기 위해 직접 합해봄

# %%
df[(df["line_nm"] == "2호선") & (df["station_nm"] == "강남")]
# Out:
#          month  day  station_ID line_nm station_nm  num
# 25           1    1         222     2호선         강남    0
# 151          1    1         222     2호선         강남    9
# 471          1    1         222     2호선         강남  167
# 797          1    1         222     2호선         강남  345
# 1123         1    1         222     2호선         강남  287
# ...        ...  ...         ...     ...        ...  ...
# 4710770     12   31         222     2호선         강남  267
# 4711098     12   31         222     2호선         강남  191
# 4711426     12   31         222     2호선         강남  106
# 4711754     12   31         222     2호선         강남   73
# 4712082     12   31         222     2호선         강남   57
#
# [14491 rows x 6 columns]

# %%
df[(df["line_nm"] == "2호선") & (df["station_nm"] == "강남")].num.sum()
# Out:
# 21400896

# %% [markdown]
# ### 환승호선 합산

# %%
subdat[subdat["sum_line_station"] == 0] # 0인 값 있음
# Out:
#     line_nm station_nm  sum_line_station
# 67      3호선        충무로                 0
# 177     6호선        연신내                 0
# 178     6호선         신내                 0

# %%
subdat[subdat["station_nm"] == "충무로"] # 두 개의 역의 교차이기 때문에 3호선에는 결측
# Out:
#     line_nm station_nm  sum_line_station
# 67      3호선        충무로                 0
# 110     4호선        충무로           5810818

# %%
subdat[["station_nm", "sum_line_station"]]
# Out:
#     station_nm  sum_line_station
# 0          서울역           6656302
# 1           시청           2373206
# 2           종각           4975912
# 3         종로3가           4467501
# 4         종로5가           3587983
# ..         ...               ...
# 326         화계            813936
# 327        가오리           1004799
# 328      북한산우이            729124
# 329         정릉           1028470
# 330   4.19민주묘지            688568
#
# [331 rows x 2 columns]

# %%
# line_nm, station_nm 그룹으로 묶음
## ex) 4호선-노원 , 7호선-노원 이런 식으로 한 그룹 형성
## sum_line_station 을 생성해 위의 각 속성에 해당되는 num값을 다 합해 해당 열에 값을 채움 (중복값 있는 상태)
ex["sum_line_station"] = ex.groupby(by = [ 'station_nm'])["num"].transform(sum)

## 위에서 만든 데이터 프레임에서 월/일을 제외하고 중복값을 제거하면 1년 전체에 대한 합산 구하기 가능
subdat2=ex[["station_nm","sum_line_station"]].drop_duplicates()

## 호선명 기준으로 나열
#subdat2 = subdat2.sort_values(["line_nm"],ascending=True)
subdat2 = subdat2.set_index(pd.Index([i for i in range(285)]))
subdat2
# Out:
#     station_nm  sum_line_station
# 0          서울역          10320897
# 1           시청           7497229
# 2           종각           4975912
# 3         종로3가           9730133
# 4         종로5가           3587983
# ..         ...               ...
# 280        학여울            459755
# 281       둔촌오륜            229237
# 282         신내                 0
# 283         미사           1217818
# 284       하남풍산            478131
#
# [285 rows x 2 columns]

# %%
subdat3=subdat.groupby("station_nm", as_index=False).agg(",".join)
subdat3
# Out:
# C:\Users\ajm10\AppData\Local\Temp\ipykernel_14940\1574292293.py:1: FutureWarning: ['sum_line_station'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   subdat3=subdat.groupby("station_nm", as_index=False).agg(",".join)
#       station_nm  line_nm
# 0       4.19민주묘지    우이신설선
# 1           가락시장  3호선,8호선
# 2        가산디지털단지      7호선
# 3             가양      9호선
# 4            가오리    우이신설선
# ..           ...      ...
# 280           화곡      5호선
# 281  화랑대(서울여대입구)      6호선
# 282    회현(남대문시장)      4호선
# 283        효창공원앞      6호선
# 284    흑석(중앙대입구)      9호선
#
# [285 rows x 2 columns]

# %%
# 정렬 동일시
subdat2=subdat2.sort_values(["station_nm"],ascending=True)
subdat2=subdat2.set_index(pd.Index([i for i in range(285)]))

# 정렬 동일시
subdat3=subdat3.sort_values(["station_nm"],ascending=True)
subdat3=subdat3.set_index(pd.Index([i for i in range(285)]))

# %%
result=pd.concat([subdat2,subdat3[["line_nm"]]], axis=1, join='inner')
result=result[["line_nm", "station_nm", 'sum_line_station']]
result
# Out:
#      line_nm   station_nm  sum_line_station
# 0      우이신설선     4.19민주묘지            688568
# 1    3호선,8호선         가락시장           4401586
# 2        7호선      가산디지털단지           8574201
# 3        9호선           가양           4503640
# 4      우이신설선          가오리           1004799
# ..       ...          ...               ...
# 280      5호선           화곡           6689936
# 281      6호선  화랑대(서울여대입구)           2202048
# 282      4호선    회현(남대문시장)           5285611
# 283      6호선        효창공원앞           1545629
# 284      9호선    흑석(중앙대입구)           1856514
#
# [285 rows x 3 columns]

# %% [markdown]
# ##### 환승구간 합산

# %%
trans = subdat.copy()
trans = trans.groupby ("station_nm").count()
trans[ trans.line_nm > 1]
# Out:
#                 line_nm  sum_line_station
# station_nm
# 가락시장                  2                 2
# 건대입구                  2                 2
# 고속터미널                 3                 3
# 공덕                    2                 2
# 교대(법원.검찰청)            2                 2
# 군자(능동)                2                 2
# 김포공항                  2                 2
# 노원                    2                 2
# 당산                    2                 2
# 대림(구로구청)              2                 2
# 동대문                   2                 2
# 동대문역사문화공원(DDP)        3                 3
# 동묘앞                   2                 2
# 동작(현충원)               2                 2
# 보문                    2                 2
# 불광                    2                 2
# 사당                    2                 2
# 삼각지                   2                 2
# 서울역                   2                 2
# 석촌                    2                 2
# 성신여대입구(돈암)            2                 2
# ...

# %% [markdown]
# ## 호선명 - 역명 (환승 고려)

# %%
month_sum = df.drop_duplicates(["line_nm", "station_nm"])
month_sum = month_sum[["line_nm", "station_nm"]]

month_sum = month_sum.sort_values(["line_nm"],ascending=True)
month_sum = month_sum.set_index(pd.Index([i for i in range(331)]))

month_sum
# Out:
#     line_nm station_nm
# 0       1호선        서울역
# 1       1호선         시청
# 2       1호선         종각
# 3       1호선       종로3가
# 4       1호선       종로5가
# ..      ...        ...
# 326   우이신설선         화계
# 327   우이신설선        가오리
# 328   우이신설선      북한산우이
# 329   우이신설선         정릉
# 330   우이신설선   4.19민주묘지
#
# [331 rows x 2 columns]

# %% [markdown]
# ### 1월에 해당하는 데이터 프레임 df_1

# %%
df_1 = df[df.month == 1]
df_1
# Out:
#         month  day  station_ID line_nm  station_nm  num
# 0           1    1         150     1호선         서울역    1
# 1           1    1         151     1호선          시청    0
# 2           1    1         152     1호선          종각    2
# 3           1    1         153     1호선        종로3가    1
# 4           1    1         154     1호선        종로5가    0
# ...       ...  ...         ...     ...         ...  ...
# 407562      1   31        4709   우이신설선      북한산보국문  115
# 407563      1   31        4710   우이신설선          정릉   65
# 407564      1   31        4711   우이신설선  성신여대입구(돈암)   29
# 407565      1   31        4712   우이신설선          보문   17
# 407566      1   31        4713   우이신설선         신설동    9
#
# [407567 rows x 6 columns]

# %%
## 코드 맞나 확인

print(df_1[(df_1.line_nm==month_sum.line_nm[0])&(df_1.station_nm==month_sum.station_nm[0])].num.sum())

#  환승함 - 1호선 4호선
print(df_1[(df_1.station_nm == "서울역") & (df_1.line_nm == "1호선")].num.sum())
# Out:
# 857003
# 857003

# %%
df_1[(df_1.line_nm==month_sum.line_nm[38])].num.sum()
# Out:
# 34743098

# %%
df_1[df_1["station_nm"]=="충무로"]
# Out:
#         month  day  station_ID line_nm station_nm  num
# 66          1    1         423     4호선        충무로    0
# 225         1    1         423     4호선        충무로    0
# 547         1    1         423     4호선        충무로   81
# 873         1    1         423     4호선        충무로  208
# 1199        1    1         423     4호선        충무로  248
# ...       ...  ...         ...     ...        ...  ...
# 406044      1   31         423     4호선        충무로  220
# 406370      1   31         423     4호선        충무로  219
# 406696      1   31         423     4호선        충무로  201
# 407022      1   31         423     4호선        충무로  176
# 407348      1   31         423     4호선        충무로  142
#
# [1303 rows x 6 columns]

# %%
month_sum_1 = month_sum.copy()
month_sum_1["sum"] = 0

# %%
for i in range(331):
        month_sum_1["sum"][i]= df_1[(df_1.line_nm==month_sum.line_nm[i])&(df_1.station_nm==month_sum.station_nm[i])].num.sum()
# Out:
# C:\Users\ajm10\AppData\Local\Temp\ipykernel_6916\4214102409.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   month_sum_1["sum"][i]= df_1[(df_1.line_nm==month_sum.line_nm[i])&(df_1.station_nm==month_sum.station_nm[i])].num.sum()

# %%
month_sum_1
# Out:
#     line_nm station_nm     sum
# 0       1호선        서울역  857003
# 1       1호선         시청  308404
# 2       1호선         종각  597961
# 3       1호선       종로3가  559265
# 4       1호선       종로5가  421826
# ..      ...        ...     ...
# 326   우이신설선         화계   81420
# 327   우이신설선        가오리   99252
# 328   우이신설선      북한산우이   63053
# 329   우이신설선         정릉   99529
# 330   우이신설선   4.19민주묘지   63427
#
# [331 rows x 3 columns]

# %%
month_sum_1[month_sum_1["sum"] == 0]
# Out:
#     line_nm station_nm  sum
# 67      3호선        충무로    0
# 144     5호선         미사    0
# 162     5호선       하남풍산    0
# 177     6호선        연신내    0
# 178     6호선         신내    0

# %% [markdown]
# 미사, 하남풍산은 서울 안의 역이 아니라 신경쓰지 않아도 됨
# 그러나 충무로, 신내, 연신내는 다시 확인

# %%
# 환승구간이라 다른 곳에 count

print("충무로  ",df[df.station_nm == "충무로"].line_nm.unique())

print("연신내  ",df[df.station_nm == "연신내"].line_nm.unique())
# Out:
# 환승구간이라 다른 곳에 count - 충무로  ['4호선' '3호선']
# 연신내   ['3호선' '6호선']

# %%
month_sum_1[month_sum_1.station_nm == "충무로"]
# Out:
#     line_nm station_nm     sum
# 67      3호선        충무로       0
# 110     4호선        충무로  628237

# %%
month_sum_1[month_sum_1.station_nm == "연신내"]
# Out:
#     line_nm station_nm     sum
# 74      3호선        연신내  867324
# 177     6호선        연신내       0

# %%
df[df.station_nm == "신내"]
# Out:
#          month  day  station_ID line_nm station_nm  num
# 131165       1   11        2649     6호선         신내    0
# 245033       1   19        2649     6호선         신내    0
# 390249       1   30        2649     6호선         신내    0
# 446591       2    4        2649     6호선         신내    0
# 1122459      3   26        2649     6호선         신내    0
# 1521933      4   26        2649     6호선         신내    0
# 1661187      5    7        2649     6호선         신내    0
# 1739963      5   13        2649     6호선         신내    0
# 1784770      5   17        2649     6호선         신내    0
# 1791617      5   17        2649     6호선         신내    0
# 2167613      6   16        2649     6호선         신내    0
# 2247778      6   22        2649     6호선         신내    0
# 2339410      6   29        2649     6호선         신내    0
# 2378028      7    2        2649     6호선         신내    0
# 2498468      7   12        2649     6호선         신내    0
# 2629263      7   22        2649     6호선         신내    0
# ...

# %% [markdown]
# ##### 신내는 값이 없다

# %% [markdown]
# ### 2월에 해당하는 데이터 프레임 df_2

# %%
df_2 = df[df.month == 2]
df_2
# Out:
#         month  day  station_ID line_nm  station_nm  num
# 407567      2    1         150     1호선         서울역  152
# 407568      2    1         151     1호선          시청   28
# 407569      2    1         152     1호선          종각   49
# 407570      2    1         153     1호선        종로3가   55
# 407571      2    1         154     1호선        종로5가   15
# ...       ...  ...         ...     ...         ...  ...
# 788333      2   29        4709   우이신설선      북한산보국문   45
# 788334      2   29        4710   우이신설선          정릉   21
# 788335      2   29        4711   우이신설선  성신여대입구(돈암)   25
# 788336      2   29        4712   우이신설선          보문   19
# 788337      2   29        4713   우이신설선         신설동    9
#
# [380771 rows x 6 columns]

# %%
month_sum_2 = month_sum.copy()
month_sum_2["sum"] = 0

for i in range(331):
        month_sum_2["sum"][i]= df_2[(df_2.line_nm==month_sum.line_nm[i])&(df_2.station_nm==month_sum.station_nm[i])].num.sum()
# Out:
# C:\Users\ajm10\AppData\Local\Temp\ipykernel_6916\2412058925.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   month_sum_2["sum"][i]= df_2[(df_2.line_nm==month_sum.line_nm[i])&(df_2.station_nm==month_sum.station_nm[i])].num.sum()

# %%
month_sum_2
# Out:
#     line_nm station_nm     sum
# 0       1호선        서울역  603013
# 1       1호선         시청  228214
# 2       1호선         종각  468055
# 3       1호선       종로3가  405475
# 4       1호선       종로5가  311172
# ..      ...        ...     ...
# 326   우이신설선         화계   67957
# 327   우이신설선        가오리   83842
# 328   우이신설선      북한산우이   51780
# 329   우이신설선         정릉   83317
# 330   우이신설선   4.19민주묘지   54120
#
# [331 rows x 3 columns]

# %%
month_sum_2[month_sum_2["sum"] == 0]
# Out:
#     line_nm station_nm  sum
# 67      3호선        충무로    0
# 144     5호선         미사    0
# 162     5호선       하남풍산    0
# 177     6호선        연신내    0
# 178     6호선         신내    0

# %% [markdown]
# ##### 1월과 동일

# %% [markdown]
# ### 3월 - 12월 코드

# %%
df_3 = df[df.month == 3]

month_sum_3 = month_sum.copy()
month_sum_3["sum"] = 0

for i in range(331):
        month_sum_3["sum"][i]= df_3[(df_3.line_nm==month_sum.line_nm[i])&(df_3.station_nm==month_sum.station_nm[i])].num.sum()
        
month_sum_3
# Out:
# C:\Users\ajm10\AppData\Local\Temp\ipykernel_6916\361241996.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   month_sum_3["sum"][i]= df_3[(df_3.line_nm==month_sum.line_nm[i])&(df_3.station_nm==month_sum.station_nm[i])].num.sum()
#     line_nm station_nm     sum
# 0       1호선        서울역  409353
# 1       1호선         시청  164826
# 2       1호선         종각  344645
# 3       1호선       종로3가  307157
# 4       1호선       종로5가  247007
# ..      ...        ...     ...
# 326   우이신설선         화계   59389
# 327   우이신설선        가오리   72872
# 328   우이신설선      북한산우이   51551
# 329   우이신설선         정릉   73421
# 330   우이신설선   4.19민주묘지   48410
#
# [331 rows x 3 columns]

# %%
month_sum_3[month_sum_3["sum"] == 0]
# Out:
#     line_nm station_nm  sum
# 67      3호선        충무로    0
# 144     5호선         미사    0
# 162     5호선       하남풍산    0
# 177     6호선        연신내    0
# 178     6호선         신내    0

# %%
df_4 = df[df.month == 4]

month_sum_4 = month_sum.copy()
month_sum_4["sum"] = 0

for i in range(331):
        month_sum_4["sum"][i]= df_4[(df_4.line_nm==month_sum.line_nm[i])&(df_4.station_nm==month_sum.station_nm[i])].num.sum()
        
month_sum_4
# Out:
# C:\Users\ajm10\AppData\Local\Temp\ipykernel_6916\2516312563.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   month_sum_4["sum"][i]= df_4[(df_4.line_nm==month_sum.line_nm[i])&(df_4.station_nm==month_sum.station_nm[i])].num.sum()
#     line_nm station_nm     sum
# 0       1호선        서울역  472721
# 1       1호선         시청  163843
# 2       1호선         종각  371467
# 3       1호선       종로3가  349140
# 4       1호선       종로5가  275196
# ..      ...        ...     ...
# 326   우이신설선         화계   62226
# 327   우이신설선        가오리   76151
# 328   우이신설선      북한산우이   63008
# 329   우이신설선         정릉   78662
# 330   우이신설선   4.19민주묘지   53330
#
# [331 rows x 3 columns]

# %%
month_sum_4[month_sum_4["sum"] == 0]
# Out:
#     line_nm station_nm  sum
# 67      3호선        충무로    0
# 144     5호선         미사    0
# 162     5호선       하남풍산    0
# 177     6호선        연신내    0
# 178     6호선         신내    0

# %%
df_5 = df[df.month == 5]

month_sum_5 = month_sum.copy()
month_sum_5["sum"] = 0

for i in range(331):
        month_sum_5["sum"][i]= df_5[(df_5.line_nm==month_sum.line_nm[i])&(df_5.station_nm==month_sum.station_nm[i])].num.sum()
        
month_sum_5
# Out:
# C:\Users\ajm10\AppData\Local\Temp\ipykernel_6916\2027979932.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   month_sum_5["sum"][i]= df_5[(df_5.line_nm==month_sum.line_nm[i])&(df_5.station_nm==month_sum.station_nm[i])].num.sum()
#     line_nm station_nm     sum
# 0       1호선        서울역  549163
# 1       1호선         시청  183157
# 2       1호선         종각  410591
# 3       1호선       종로3가  391192
# 4       1호선       종로5가  315929
# ..      ...        ...     ...
# 326   우이신설선         화계   67235
# 327   우이신설선        가오리   83549
# 328   우이신설선      북한산우이   66729
# 329   우이신설선         정릉   87295
# 330   우이신설선   4.19민주묘지   60662
#
# [331 rows x 3 columns]

# %%
month_sum_5[month_sum_5["sum"] == 0]
# Out:
#     line_nm station_nm  sum
# 67      3호선        충무로    0
# 144     5호선         미사    0
# 162     5호선       하남풍산    0
# 177     6호선        연신내    0
# 178     6호선         신내    0

# %%
df_6 = df[df.month == 6]

month_sum_6 = month_sum.copy()
month_sum_6["sum"] = 0

for i in range(331):
        month_sum_6["sum"][i]= df_6[(df_6.line_nm==month_sum.line_nm[i])&(df_6.station_nm==month_sum.station_nm[i])].num.sum()
        
month_sum_6
# Out:
# C:\Users\ajm10\AppData\Local\Temp\ipykernel_6916\170568114.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   month_sum_6["sum"][i]= df_6[(df_6.line_nm==month_sum.line_nm[i])&(df_6.station_nm==month_sum.station_nm[i])].num.sum()
#     line_nm station_nm     sum
# 0       1호선        서울역  575653
# 1       1호선         시청  199833
# 2       1호선         종각  450120
# 3       1호선       종로3가  384201
# 4       1호선       종로5가  314588
# ..      ...        ...     ...
# 326   우이신설선         화계   69460
# 327   우이신설선        가오리   88026
# 328   우이신설선      북한산우이   64813
# 329   우이신설선         정릉   90103
# 330   우이신설선   4.19민주묘지   60664
#
# [331 rows x 3 columns]

# %%
month_sum_6[month_sum_6["sum"] == 0]
# Out:
#     line_nm station_nm  sum
# 67      3호선        충무로    0
# 144     5호선         미사    0
# 162     5호선       하남풍산    0
# 177     6호선        연신내    0
# 178     6호선         신내    0

# %%
df_7 = df[df.month == 7]

month_sum_7 = month_sum.copy()
month_sum_7["sum"] = 0

for i in range(331):
        month_sum_7["sum"][i]= df_7[(df_7.line_nm==month_sum.line_nm[i])&(df_7.station_nm==month_sum.station_nm[i])].num.sum()
        
month_sum_7
# Out:
# C:\Users\ajm10\AppData\Local\Temp\ipykernel_6916\2187595062.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   month_sum_7["sum"][i]= df_7[(df_7.line_nm==month_sum.line_nm[i])&(df_7.station_nm==month_sum.station_nm[i])].num.sum()
#     line_nm station_nm     sum
# 0       1호선        서울역  635785
# 1       1호선         시청  225482
# 2       1호선         종각  496537
# 3       1호선       종로3가  431991
# 4       1호선       종로5가  337766
# ..      ...        ...     ...
# 326   우이신설선         화계   73906
# 327   우이신설선        가오리   92446
# 328   우이신설선      북한산우이   70190
# 329   우이신설선         정릉   95546
# 330   우이신설선   4.19민주묘지   63779
#
# [331 rows x 3 columns]

# %%
month_sum_7[month_sum_7["sum"] == 0]
# Out:
#     line_nm station_nm  sum
# 67      3호선        충무로    0
# 144     5호선         미사    0
# 162     5호선       하남풍산    0
# 177     6호선        연신내    0
# 178     6호선         신내    0

# %%
df_8 = df[df.month == 8]

month_sum_8 = month_sum.copy()
month_sum_8["sum"] = 0

for i in range(331):
        month_sum_8["sum"][i]= df_8[(df_8.line_nm==month_sum.line_nm[i])&(df_8.station_nm==month_sum.station_nm[i])].num.sum()
        
month_sum_8
# Out:
# C:\Users\ajm10\AppData\Local\Temp\ipykernel_6916\2913855797.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   month_sum_8["sum"][i]= df_8[(df_8.line_nm==month_sum.line_nm[i])&(df_8.station_nm==month_sum.station_nm[i])].num.sum()
#     line_nm station_nm     sum
# 0       1호선        서울역  526535
# 1       1호선         시청  178988
# 2       1호선         종각  391433
# 3       1호선       종로3가  345603
# 4       1호선       종로5가  273422
# ..      ...        ...     ...
# 326   우이신설선         화계   63031
# 327   우이신설선        가오리   78067
# 328   우이신설선      북한산우이   55227
# 329   우이신설선         정릉   77798
# 330   우이신설선   4.19민주묘지   53016
#
# [331 rows x 3 columns]

# %%
month_sum_8[month_sum_8["sum"] == 0]
# Out:
#     line_nm station_nm  sum
# 67      3호선        충무로    0
# 177     6호선        연신내    0
# 178     6호선         신내    0

# %%
df_9 = df[df.month == 9]

month_sum_9 = month_sum.copy()
month_sum_9["sum"] = 0

for i in range(331):
        month_sum_9["sum"][i]= df_9[(df_9.line_nm==month_sum.line_nm[i])&(df_9.station_nm==month_sum.station_nm[i])].num.sum()
        
month_sum_9
# Out:
# C:\Users\ajm10\AppData\Local\Temp\ipykernel_6916\2796989805.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   month_sum_9["sum"][i]= df_9[(df_9.line_nm==month_sum.line_nm[i])&(df_9.station_nm==month_sum.station_nm[i])].num.sum()
#     line_nm station_nm     sum
# 0       1호선        서울역  456133
# 1       1호선         시청  159151
# 2       1호선         종각  324598
# 3       1호선       종로3가  294415
# 4       1호선       종로5가  260734
# ..      ...        ...     ...
# 326   우이신설선         화계   63784
# 327   우이신설선        가오리   78182
# 328   우이신설선      북한산우이   58151
# 329   우이신설선         정릉   79651
# 330   우이신설선   4.19민주묘지   53934
#
# [331 rows x 3 columns]

# %%
month_sum_9[month_sum_9["sum"] == 0]
# Out:
#     line_nm station_nm  sum
# 67      3호선        충무로    0
# 177     6호선        연신내    0
# 178     6호선         신내    0

# %%
df_10 = df[df.month == 10]

month_sum_10 = month_sum.copy()
month_sum_10["sum"] = 0

for i in range(331):
        month_sum_10["sum"][i]= df_10[(df_10.line_nm==month_sum.line_nm[i])&(df_10.station_nm==month_sum.station_nm[i])].num.sum()
        
month_sum_10
# Out:
# C:\Users\ajm10\AppData\Local\Temp\ipykernel_6916\3945632535.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   month_sum_10["sum"][i]= df_10[(df_10.line_nm==month_sum.line_nm[i])&(df_10.station_nm==month_sum.station_nm[i])].num.sum()
#     line_nm station_nm     sum
# 0       1호선        서울역  552635
# 1       1호선         시청  192043
# 2       1호선         종각  402243
# 3       1호선       종로3가  368044
# 4       1호선       종로5가  298116
# ..      ...        ...     ...
# 326   우이신설선         화계   70588
# 327   우이신설선        가오리   86217
# 328   우이신설선      북한산우이   73693
# 329   우이신설선         정릉   90453
# 330   우이신설선   4.19민주묘지   62837
#
# [331 rows x 3 columns]

# %%
month_sum_10[month_sum_10["sum"] == 0]
# Out:
#     line_nm station_nm  sum
# 67      3호선        충무로    0
# 177     6호선        연신내    0
# 178     6호선         신내    0

# %%
df_11 = df[df.month == 11]

month_sum_11 = month_sum.copy()
month_sum_11["sum"] = 0

for i in range(331):
        month_sum_11["sum"][i]= df_11[(df_11.line_nm==month_sum.line_nm[i])&(df_11.station_nm==month_sum.station_nm[i])].num.sum()
        
month_sum_11
# Out:
# C:\Users\ajm10\AppData\Local\Temp\ipykernel_6916\584237238.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   month_sum_11["sum"][i]= df_11[(df_11.line_nm==month_sum.line_nm[i])&(df_11.station_nm==month_sum.station_nm[i])].num.sum()
#     line_nm station_nm     sum
# 0       1호선        서울역  585361
# 1       1호선         시청  209093
# 2       1호선         종각  412172
# 3       1호선       종로3가  367170
# 4       1호선       종로5가  289159
# ..      ...        ...     ...
# 326   우이신설선         화계   71462
# 327   우이신설선        가오리   88321
# 328   우이신설선      북한산우이   61596
# 329   우이신설선         정릉   92839
# 330   우이신설선   4.19민주묘지   62295
#
# [331 rows x 3 columns]

# %%
month_sum_11[month_sum_11["sum"] == 0]
# Out:
#     line_nm station_nm  sum
# 67      3호선        충무로    0
# 177     6호선        연신내    0
# 178     6호선         신내    0

# %%
df_12 = df[df.month == 12]

month_sum_12 = month_sum.copy()
month_sum_12["sum"] = 0

for i in range(331):
        month_sum_12["sum"][i]= df_12[(df_12.line_nm==month_sum.line_nm[i])&(df_12.station_nm==month_sum.station_nm[i])].num.sum()
        
month_sum_12
# Out:
# C:\Users\ajm10\AppData\Local\Temp\ipykernel_6916\253387357.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   month_sum_12["sum"][i]= df_12[(df_12.line_nm==month_sum.line_nm[i])&(df_12.station_nm==month_sum.station_nm[i])].num.sum()
#     line_nm station_nm     sum
# 0       1호선        서울역  432947
# 1       1호선         시청  160172
# 2       1호선         종각  306090
# 3       1호선       종로3가  263848
# 4       1호선       종로5가  243068
# ..      ...        ...     ...
# 326   우이신설선         화계   63478
# 327   우이신설선        가오리   77874
# 328   우이신설선      북한산우이   49333
# 329   우이신설선         정릉   79856
# 330   우이신설선   4.19민주묘지   52094
#
# [331 rows x 3 columns]

# %%
month_sum_12[month_sum_12["sum"] == 0]
# Out:
#     line_nm station_nm  sum
# 67      3호선        충무로    0
# 177     6호선        연신내    0
# 178     6호선         신내    0

# %%
df[(df.line_nm=="5호선")&(df.station_nm=="하남풍산")]
# Out:
#          month  day  station_ID line_nm station_nm  num
# 2840264      8    8        2564     5호선       하남풍산    0
# 2840592      8    8        2564     5호선       하남풍산    2
# 2840920      8    8        2564     5호선       하남풍산   86
# 2841248      8    8        2564     5호선       하남풍산   51
# 2841576      8    8        2564     5호선       하남풍산   44
# ...        ...  ...         ...     ...        ...  ...
# 4710910     12   31        2564     5호선       하남풍산   65
# 4711238     12   31        2564     5호선       하남풍산   52
# 4711566     12   31        2564     5호선       하남풍산   36
# 4711894     12   31        2564     5호선       하남풍산   11
# 4712220     12   31        2564     5호선       하남풍산   23
#
# [5711 rows x 6 columns]

# %% [markdown]
# ### 모든 month_sum_[i] 의 값을 확인한 결과,
#
# - 신내(6호선) 기본 df 자체에 데이터 없음
#
# - 연신내(6호선) 데이터 업음
# - 충무로(3호선) 데이터 없음
#     -> 다른 호선에 데이터 존재함
#
# - 하남풍산, 미사(5호선) 의 경우 서울 밖의 역이기 때문에 drop함
#
# 또한 8월을 기준으로 하남풍산, 미사는 value 존재
#
# ### 공통적으로 0을 갖는 행들은 위와 같은 이유로 도수분포표를 확인시 유의

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib as mpl

# %%
month_sum_1.plot.bar(x="n", y="sum", rot=0, fontsize=5)
# Out:
# <AxesSubplot:xlabel='n'>

# %%
f, ax = plt.subplots(4,3)
f.set_size_inches((20, 15))
plt.subplots_adjust(wspace = 0.3, hspace = 0.3)

sns.distplot(month_sum_1['sum'], ax=ax[0,0])
sns.distplot(month_sum_2['sum'], ax=ax[0,1])
sns.distplot(month_sum_3['sum'], ax=ax[0,2])

sns.distplot(month_sum_4['sum'], ax=ax[1,0])
sns.distplot(month_sum_5['sum'], ax=ax[1,1])
sns.distplot(month_sum_6['sum'], ax=ax[1,2])

sns.distplot(month_sum_7['sum'], ax=ax[2,0])
sns.distplot(month_sum_8['sum'], ax=ax[2,1])
sns.distplot(month_sum_9['sum'], ax=ax[2,2])

sns.distplot(month_sum_10['sum'], ax=ax[3,0])
sns.distplot(month_sum_11['sum'], ax=ax[3,1])
sns.distplot(month_sum_12['sum'], ax=ax[3,2])
# Out:
# C:\Users\ajm10\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\ajm10\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %% [markdown]
# 비슷한 형태인 것을 확인할 수 있고 각각 상위 레코드만 보고 싶은데,,,,

# %% [markdown]
# ### 지금 구분이 호선 - 역명 이렇게 되어 있는데 사실 역명만 따로 빼내어서 확인해봐야 하는 거?

# %%
result
# Out:
#      line_nm   station_nm  sum_line_station
# 0      우이신설선     4.19민주묘지            688568
# 1    3호선,8호선         가락시장           4401586
# 2        7호선      가산디지털단지           8574201
# 3        9호선           가양           4503640
# 4      우이신설선          가오리           1004799
# ..       ...          ...               ...
# 280      5호선           화곡           6689936
# 281      6호선  화랑대(서울여대입구)           2202048
# 282      4호선    회현(남대문시장)           5285611
# 283      6호선        효창공원앞           1545629
# 284      9호선    흑석(중앙대입구)           1856514
#
# [285 rows x 3 columns]

# %%
result.

# %%
goo=sample2.copy()

# %%
goo
# Out:
#      지역구                                         station_nm  count
# 0    강남구  삼성(2), 선릉(2), 역삼(2), 강남(2), 압구정(3), 신사(3), 매봉(...     13
# 1    강동구  천호(5), 강동(5), 길동(5), 굽은다리(5), 명일(5), 고덕(5), 상일...     11
# 2    강북구                             수유(4), 미아(4), 미아사거리(4)      3
# 3    강서구  방화(5), 개화산(5), 김포공항(5), 송정(5), 마곡(5), 발산(5), 우...      9
# 4    관악구                     낙성대(2), 서울대입구(2), 봉천(2), 신림(2)      4
# 5    광진구  건대입구(2), 구의(2), 강변(2), 군자(5), 아차산(5), 광나루(5), ...     10
# 6    구로구  구로디지털단지(2), 대림(2), 신도림(2), 도림천(2), 남구로(7), 천왕(...      7
# 7    금천구                                         가산디지털단지(7)      1
# 8    노원구  당고개(4), 상계(4), 노원(4), 태릉입구(6), 화랑대(6), 수락산(7),...     12
# 9    도봉구                               창동(4), 쌍문(4), 도봉산(7)      3
# 10  동대문구             신설동(1), 제기동(1), 청량리(1), 신설동(2), 장한평(5)      5
# 11   동작구  사당(2), 신대방(2), 동작(4), 이수(4), 사당(4), 이수(7), 남성(...     12
# 12   마포구  합정(2), 홍대입구(2), 신촌(2), 이대(2), 아현(2), 마포(5), 공덕...      8
# ...

# %%
goo[["count"]].sum()
# Out:
# count    211
# dtype: int64

# %%
for i in range(25):
    arr=goo.station_nm[i].split(",")
    
    for j in range(len(arr)):
          print("'",arr[j],"':",
                "['",goo.지역구[i],"'],")
# Out:
# ' 삼성(2) ': [' 강남구 '],
# '  선릉(2) ': [' 강남구 '],
# '  역삼(2) ': [' 강남구 '],
# '  강남(2) ': [' 강남구 '],
# '  압구정(3) ': [' 강남구 '],
# '  신사(3) ': [' 강남구 '],
# '  매봉(3) ': [' 강남구 '],
# '  도곡(3) ': [' 강남구 '],
# '  대치(3) ': [' 강남구 '],
# '  학여울(3) ': [' 강남구 '],
# '  대청(3) ': [' 강남구 '],
# '  일원(3) ': [' 강남구 '],
# '  수서(3) ': [' 강남구 '],
# ' 천호(5) ': [' 강동구 '],
# '  강동(5) ': [' 강동구 '],
# '  길동(5) ': [' 강동구 '],
# '  굽은다리(5) ': [' 강동구 '],
# '  명일(5) ': [' 강동구 '],
# '  고덕(5) ': [' 강동구 '],
# '  상일동(5) ': [' 강동구 '],
# '  둔촌동(5) ': [' 강동구 '],
# '  암사(5) ': [' 강동구 '],
# '  천호(8) ': [' 강동구 '],
# '  강동구청(8) ': [' 강동구 '],
# ' 수유(4) ': [' 강북구 '],
# '  미아(4) ': [' 강북구 '],
# '  미아사거리(4) ': [' 강북구 '],
# ' 방화(5) ': [' 강서구 '],
# '  개화산(5) ': [' 강서구 '],
# '  김포공항(5) ': [' 강서구 '],
# '  송정(5) ': [' 강서구 '],
# '  마곡(5) ': [' 강서구 '],
# '  발산(5) ': [' 강서구 '],
# '  우장산(5) ': [' 강서구 '],
# '  화곡(5) ': [' 강서구 '],
# '  까치산(5) ': [' 강서구 '],
# ' 낙성대(2) ': [' 관악구 '],
# '  서울대입구(2) ': [' 관악구 '],
# '  봉천(2) ': [' 관악구 '],
# ...

# %%
B={' 삼성(2) ': [' 강남구 '],
'  선릉(2) ': [' 강남구 '],
'  역삼(2) ': [' 강남구 '],
'  강남(2) ': [' 강남구 '],
'  압구정(3) ': [' 강남구 '],
'  신사(3) ': [' 강남구 '],
'  매봉(3) ': [' 강남구 '],
'  도곡(3) ': [' 강남구 '],
'  대치(3) ': [' 강남구 '],
'  학여울(3) ': [' 강남구 '],
'  대청(3) ': [' 강남구 '],
'  일원(3) ': [' 강남구 '],
'  수서(3) ': [' 강남구 '],
' 천호(5) ': [' 강동구 '],
'  강동(5) ': [' 강동구 '],
'  길동(5) ': [' 강동구 '],
'  굽은다리(5) ': [' 강동구 '],
'  명일(5) ': [' 강동구 '],
'  고덕(5) ': [' 강동구 '],
'  상일동(5) ': [' 강동구 '],
'  둔촌동(5) ': [' 강동구 '],
'  암사(5) ': [' 강동구 '],
'  천호(8) ': [' 강동구 '],
'  강동구청(8) ': [' 강동구 '],
' 수유(4) ': [' 강북구 '],
'  미아(4) ': [' 강북구 '],
'  미아사거리(4) ': [' 강북구 '],
' 방화(5) ': [' 강서구 '],
'  개화산(5) ': [' 강서구 '],
'  김포공항(5) ': [' 강서구 '],
'  송정(5) ': [' 강서구 '],
'  마곡(5) ': [' 강서구 '],
'  발산(5) ': [' 강서구 '],
'  우장산(5) ': [' 강서구 '],
'  화곡(5) ': [' 강서구 '],
'  까치산(5) ': [' 강서구 '],
' 낙성대(2) ': [' 관악구 '],
'  서울대입구(2) ': [' 관악구 '],
'  봉천(2) ': [' 관악구 '],
'  신림(2) ': [' 관악구 '],
' 건대입구(2) ': [' 광진구 '],
'  구의(2) ': [' 광진구 '],
'  강변(2) ': [' 광진구 '],
'  군자(5) ': [' 광진구 '],
'  아차산(5) ': [' 광진구 '],
'  광나루(5) ': [' 광진구 '],
'  중곡(7) ': [' 광진구 '],
'  군자(7) ': [' 광진구 '],
'  어린이대공원(7) ': [' 광진구 '],
'  건대입구(7) ': [' 광진구 '],
' 구로디지털단지(2) ': [' 구로구 '],
'  대림(2) ': [' 구로구 '],
'  신도림(2) ': [' 구로구 '],
'  도림천(2) ': [' 구로구 '],
'  남구로(7) ': [' 구로구 '],
'  천왕(7) ': [' 구로구 '],
'  온수(7) ': [' 구로구 '],
' 가산디지털단지(7) ': [' 금천구 '],
' 당고개(4) ': [' 노원구 '],
'  상계(4) ': [' 노원구 '],
'  노원(4) ': [' 노원구 '],
'  태릉입구(6) ': [' 노원구 '],
'  화랑대(6) ': [' 노원구 '],
'  수락산(7) ': [' 노원구 '],
'  마들(7) ': [' 노원구 '],
'  노원(7) ': [' 노원구 '],
'  중계(7) ': [' 노원구 '],
'  하계(7) ': [' 노원구 '],
'  공릉(7) ': [' 노원구 '],
'  태릉입구(7) ': [' 노원구 '],
' 창동(4) ': [' 도봉구 '],
'  쌍문(4) ': [' 도봉구 '],
'  도봉산(7) ': [' 도봉구 '],
' 신설동(1) ': [' 동대문구 '],
'  제기동(1) ': [' 동대문구 '],
'  청량리(1) ': [' 동대문구 '],
'  신설동(2) ': [' 동대문구 '],
'  장한평(5) ': [' 동대문구 '],
' 사당(2) ': [' 동작구 '],
'  신대방(2) ': [' 동작구 '],
'  동작(4) ': [' 동작구 '],
'  이수(4) ': [' 동작구 '],
'  사당(4) ': [' 동작구 '],
'  이수(7) ': [' 동작구 '],
'  남성(7) ': [' 동작구 '],
'  숭실대입구(7) ': [' 동작구 '],
'  상도(7) ': [' 동작구 '],
'  장승배기(7) ': [' 동작구 '],
'  신대방삼거리(7) ': [' 동작구 '],
'  보라매(7) ': [' 동작구 '],
' 합정(2) ': [' 마포구 '],
'  홍대입구(2) ': [' 마포구 '],
'  신촌(2) ': [' 마포구 '],
'  이대(2) ': [' 마포구 '],
'  아현(2) ': [' 마포구 '],
'  마포(5) ': [' 마포구 '],
'  공덕(5) ': [' 마포구 '],
'  애오개(5) ': [' 마포구 '],
' 충정로(2) ': [' 서대문구 '],
'  홍제(3) ': [' 서대문구 '],
'  무악재(3) ': [' 서대문구 '],
'  독립문(3) ': [' 서대문구 '],
'  충정로(5) ': [' 서대문구 '],
' 교대(2) ': [' 서초구 '],
'  서초(2) ': [' 서초구 '],
'  방배(2) ': [' 서초구 '],
'  잠원(3) ': [' 서초구 '],
'  고속터미널(3) ': [' 서초구 '],
'  교대(3) ': [' 서초구 '],
'  남부터미널(3) ': [' 서초구 '],
'  양재(3) ': [' 서초구 '],
'  남태령(4) ': [' 서초구 '],
'  내방(7) ': [' 서초구 '],
' 상왕십리(2) ': [' 성동구 '],
'  왕십리(2) ': [' 성동구 '],
'  한양대(2) ': [' 성동구 '],
'  뚝섬(2) ': [' 성동구 '],
'  성수(2) ': [' 성동구 '],
'  용답(2) ': [' 성동구 '],
'  신답(2) ': [' 성동구 '],
'  금호(3) ': [' 성동구 '],
'  옥수(3) ': [' 성동구 '],
'  신금호(5) ': [' 성동구 '],
'  행당(5) ': [' 성동구 '],
'  왕십리(5) ': [' 성동구 '],
'  마장(5) ': [' 성동구 '],
'  답십리(5) ': [' 성동구 '],
' 길음(4) ': [' 성북구 '],
'  성신여대입구(4) ': [' 성북구 '],
'  한성대입구(4) ': [' 성북구 '],
' 잠실나루(2) ': [' 송파구 '],
'  잠실(2) ': [' 송파구 '],
'  잠실새내(2) ': [' 송파구 '],
'  종합운동장(2) ': [' 송파구 '],
'  올림픽공원(5) ': [' 송파구 '],
'  방이(5) ': [' 송파구 '],
'  오금(5) ': [' 송파구 '],
'  개롱(5) ': [' 송파구 '],
'  거여(5) ': [' 송파구 '],
'  마천(5) ': [' 송파구 '],
'  몽촌토성(8) ': [' 송파구 '],
'  잠실(8) ': [' 송파구 '],
'  석촌(8) ': [' 송파구 '],
'  송파(8) ': [' 송파구 '],
'  가락시장(8) ': [' 송파구 '],
'  문정(8) ': [' 송파구 '],
'  장지(8) ': [' 송파구 '],
'  복정(8) ': [' 송파구 '],
' 양천구청(2) ': [' 양천구 '],
'  신정네거리(2) ': [' 양천구 '],
'  신정(5) ': [' 양천구 '],
'  목동(5) ': [' 양천구 '],
'  오목교(5) ': [' 양천구 '],
' 문래(2) ': [' 영등포구 '],
'  영등포구청(2) ': [' 영등포구 '],
'  당산(2) ': [' 영등포구 '],
'  양평(5) ': [' 영등포구 '],
'  영등포구청(5) ': [' 영등포구 '],
'  영등포시장(5) ': [' 영등포구 '],
'  신길(5) ': [' 영등포구 '],
'  여의도(5) ': [' 영등포구 '],
'  여의나루(5) ': [' 영등포구 '],
'  신풍(7) ': [' 영등포구 '],
'  대림(7) ': [' 영등포구 '],
' 서울(4) ': [' 용산구 '],
'  숙대입구(4) ': [' 용산구 '],
'  삼각지(4) ': [' 용산구 '],
'  신용산(4) ': [' 용산구 '],
'  이촌(4) ': [' 용산구 '],
' 구파발(3) ': [' 은평구 '],
'  연신내(3) ': [' 은평구 '],
'  불광(3) ': [' 은평구 '],
'  녹번(3) ': [' 은평구 '],
' 종각(1) ': [' 종로구 '],
'  종로3가(1) ': [' 종로구 '],
'  종로5가(1) ': [' 종로구 '],
'  동대문(1) ': [' 종로구 '],
'  경복궁(3) ': [' 종로구 '],
'  안국(3) ': [' 종로구 '],
'  종로3가(3) ': [' 종로구 '],
'  혜화(4) ': [' 종로구 '],
'  동대문(4) ': [' 종로구 '],
'  서대문(5) ': [' 종로구 '],
'  광화문(5) ': [' 종로구 '],
'  종로3가(5) ': [' 종로구 '],
' 서울(1) ': [' 중구 '],
'  시청(1) ': [' 중구 '],
'  시청(2) ': [' 중구 '],
'  을지로입구(2) ': [' 중구 '],
'  을지로3가(2) ': [' 중구 '],
'  을지로4가(2) ': [' 중구 '],
'  동대문역사문화공원(2) ': [' 중구 '],
'  신당(2) ': [' 중구 '],
'  을지로3가(3) ': [' 중구 '],
'  충무로(3) ': [' 중구 '],
'  동대입구(3) ': [' 중구 '],
'  약수(3) ': [' 중구 '],
'  동대문역사문화공원(4) ': [' 중구 '],
'  충무로(4) ': [' 중구 '],
'  명동(4) ': [' 중구 '],
'  회현(4) ': [' 중구 '],
'  을지로4가(5) ': [' 중구 '],
'  동대문역사문화공원(5) ': [' 중구 '],
'  청구(5) ': [' 중구 '],
' 봉화산(6) ': [' 중랑구 '],
'  먹골(7) ': [' 중랑구 '],
'  중화(7) ': [' 중랑구 '],
'  상봉(7) ': [' 중랑구 '],
'  면목(7) ': [' 중랑구 '],
'  사가정(7) ': [' 중랑구 '],
'  용마산(7) ': [' 중랑구 ']}

B=pd.DataFrame(B)
B = B.transpose()
B = B.reset_index()
B = B.rename(columns={'index':'station_nm',0:"지역구"})

# %%
goo_line = B.copy()
goo_line["지역구"] = goo_line["지역구"].str[1:-1]
goo_line["station_nm"] = goo_line["station_nm"].str[1:-4]
goo_line
# Out:
#     station_nm  지역구
# 0           삼성  강남구
# 1           선릉  강남구
# 2           역삼  강남구
# 3           강남  강남구
# 4          압구정  강남구
# ..         ...  ...
# 206         중화  중랑구
# 207         상봉  중랑구
# 208         면목  중랑구
# 209        사가정  중랑구
# 210        용마산  중랑구
#
# [211 rows x 2 columns]

# %%
goo_line = goo_line.drop_duplicates() # 호선별로, 나오는 입구마다 지역구가 달라질 수 있음
goo_line
# Out:
#     station_nm  지역구
# 0           삼성  강남구
# 1           선릉  강남구
# 2           역삼  강남구
# 3           강남  강남구
# 4          압구정  강남구
# ..         ...  ...
# 206         중화  중랑구
# 207         상봉  중랑구
# 208         면목  중랑구
# 209        사가정  중랑구
# 210        용마산  중랑구
#
# [195 rows x 2 columns]

# %%
result
# Out:
#      line_nm   station_nm  sum_line_station
# 0      우이신설선     4.19민주묘지            688568
# 1    3호선,8호선         가락시장           4401586
# 2        7호선      가산디지털단지           8574201
# 3        9호선           가양           4503640
# 4      우이신설선          가오리           1004799
# ..       ...          ...               ...
# 280      5호선           화곡           6689936
# 281      6호선  화랑대(서울여대입구)           2202048
# 282      4호선    회현(남대문시장)           5285611
# 283      6호선        효창공원앞           1545629
# 284      9호선    흑석(중앙대입구)           1856514
#
# [285 rows x 3 columns]

# %%
len(result[result.line_nm=="4호선"])
# Out:
# 17

# %%
result[result.station_nm=="구월"]
# Out:
# Empty DataFrame
# Columns: [line_nm, station_nm, sum_line_station]
# Index: []

# %%
pd.concat([goo_line, result], axis=1, join='inner')
# Out:
#     station_nm  지역구  line_nm station_nm  sum_line_station
# 0           삼성  강남구    우이신설선   4.19민주묘지            688568
# 1           선릉  강남구  3호선,8호선       가락시장           4401586
# 2           역삼  강남구      7호선    가산디지털단지           8574201
# 3           강남  강남구      9호선         가양           4503640
# 4          압구정  강남구    우이신설선        가오리           1004799
# ..         ...  ...      ...        ...               ...
# 206         중화  중랑구      6호선         역촌           1025034
# 207         상봉  중랑구  3호선,6호선        연신내           8448654
# 208         면목  중랑구      9호선         염창           3955228
# 209        사가정  중랑구  2호선,5호선      영등포구청           5940592
# 210        용마산  중랑구      5호선      영등포시장           2382830
#
# [195 rows x 5 columns]

# %%
goo_line[goo_line.지역구=="노원구"]
# Out:
#    station_nm  지역구
# 58        당고개  노원구
# 59         상계  노원구
# 60         노원  노원구
# 61       태릉입구  노원구
# 62        화랑대  노원구
# 63        수락산  노원구
# 64         마들  노원구
# 66         중계  노원구
# 67         하계  노원구
# 68         공릉  노원구

# %%
goo_line[goo_line.station_nm=="석계"]#석계월계
# Out:
# Empty DataFrame
# Columns: [station_nm, 지역구]
# Index: []

# %%
result[result.station_nm=="석계"]
# Out:
#     line_nm station_nm  sum_line_station
# 146     6호선         석계           3046910

# %%
result.station_nm.unique()
# Out:
# array(['4.19민주묘지', '가락시장', '가산디지털단지', '가양', '가오리', '강남', '강남구청', '강동',
#        '강동구청', '강변(동서울터미널)', '개롱', '개화', '개화산', '거여', '건대입구',
#        '경복궁(정부서울청사)', '경찰병원', '고덕', '고려대(종암)', '고속터미널', '공덕',
#        '공릉(서울과학기술대)', '공항시장', '광나루(장신대)', '광명사거리', '광화문(세종문화회관)',
#        '광흥창(서강)', '교대(법원.검찰청)', '구로디지털단지', '구반포', '구산', '구의(광진구청)', '구파발',
#        '국회의사당', '군자(능동)', '굴포천', '굽은다리(강동구민회관앞)', '금호', '길동', '길음',
#        '김포공항', '까치산', '까치울', '낙성대(강감찬)', '남구로', '남부터미널(예술의전당)', '남성',
#        '남태령', '남한산성입구(성남법원.검찰청)', '내방', '노들', '노량진', '노원', '녹번',
#        '녹사평(용산구청)', '논현', '단대오거리', '답십리', '당고개', '당산', '대림(구로구청)', '대청',
#        '대치', '대흥(서강대앞)', '도곡', '도림천', '도봉산', '독립문', '독바위', '돌곶이', '동대문',
#        '동대문역사문화공원(DDP)', '동대입구', '동묘앞', '동작(현충원)', '둔촌동', '둔촌오륜', '등촌',
#        '디지털미디어시티', '뚝섬', '뚝섬유원지', '마곡', '마곡나루(서울식물원)', '마들', '마장', '마천',
#        '마포', '마포구청', '망원', '매봉', '먹골', '면목', '명동', '명일', '모란', '목동',
#        '몽촌토성(평화의문)', '무악재', '문래', '문정', '미사', '미아(서울사이버대학)', '미아사거리',
# ...

# %%
goo_line.to_excel("역명_지역구_수정.xlsx",encoding="utf-8")

# %%
result.to_excel("호선명_역명_2020합계_수정.xlsx",encoding="utf-8")
